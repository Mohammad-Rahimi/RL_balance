# %%
import os
import numpy as np
from myosuite.utils import gym
from stable_baselines3 import PPO
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import EvalCallback
import torch
import skvideo.io

# Custom reward wrapper to modify the cost function
class CustomRewardWrapper(gym.Wrapper):
    def __init__(self, env, distance_weight=1.0, effort_weight=0.1, stability_weight=0.05):
        super().__init__(env)
        self.distance_weight = distance_weight  # Reward forward movement
        self.effort_weight = effort_weight      # Penalize control effort
        self.stability_weight = stability_weight  # Penalize instability

    def step(self, action):
        # Handle 5-tuple return from MyoSuite's gym API
        obs, reward, terminated, truncated, info = self.env.step(action)
        
        # Unwrap to base environment for sim access
        base_env = self.env
        while hasattr(base_env, 'env'):
            base_env = base_env.env

        # Custom reward: forward distance - effort - instability
        forward_distance = base_env.sim.data.body('pelvis').xpos[0]  # X-position of pelvis
        effort = np.sum(np.square(action))  # Penalize large actions
        stability_penalty = np.sum(np.abs(base_env.sim.data.qvel[1:]))  # Exclude forward velocity
        custom_reward = (
            self.distance_weight * forward_distance
            - self.effort_weight * effort
            - self.stability_weight * stability_penalty
        )
        # Return 5-tuple to match modern SB3/Gymnasium expectation
        return obs, custom_reward, terminated, truncated, info

# Define custom neural network architecture
class CustomPolicy(ActorCriticPolicy):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.net_arch = dict(pi=[256, 128, 64], vf=[256, 128, 64])  # Policy and value network layers
        self.activation_fn = torch.nn.Tanh  # Activation function (Tanh, ReLU, etc.)

# Training function with customizable parameters
def train_ppo(env_id="myoLegWalk-v0", total_timesteps=1_000_000):
    print("Initializing environment...")
    base_env = gym.make(env_id, reset_type='random')
    env = CustomRewardWrapper(base_env, distance_weight=1.0, effort_weight=0.1, stability_weight=0.05)
    print("Environment initialized.")

    # Optional: Vectorize for faster training
    # env = make_vec_env(lambda: CustomRewardWrapper(gym.make(env_id)), n_envs=4)

    # PPO hyperparameters
    ppo_params = {
        "learning_rate": 3e-4,       # Learning rate
        "n_steps": 2048,             # Steps per update
        "batch_size": 64,            # Minibatch size
        "n_epochs": 10,              # Epochs per update
        "gamma": 0.99,               # Discount factor
        "gae_lambda": 0.95,          # GAE lambda
        "clip_range": 0.2,           # Clipping parameter
        "ent_coef": 0.01,            # Entropy coefficient
        "vf_coef": 0.5,              # Value function coefficient
        "max_grad_norm": 0.5         # Gradient clipping
    }

    # Device setup
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    # Initialize PPO with custom policy and parameters
    model = PPO(
        policy=CustomPolicy,
        env=env,
        verbose=1,
        tensorboard_log="./ppo_myo_tensorboard/",
        device=device,
        **ppo_params
    )
    print("PPO model initialized.")

    # Callback for evaluation during training
    eval_env = gym.make(env_id)
    eval_callback = EvalCallback(eval_env, eval_freq=10000, n_eval_episodes=5, verbose=1)
    print("EvalCallback initialized.")

    # Train the model
    print("Starting training...")
    model.learn(total_timesteps=total_timesteps, callback=eval_callback)
    print("Training completed.")

    # Save the model
    model.save("ppo_custom_leg_model")
    print("Model saved.")
    return model

# Testing function for walking behavior
def test_model(model, env_id="myoLegWalk-v0"):
    print("Initializing test environment...")
    env = gym.make(env_id, reset_type='random')
    env.reset()
    frames = []

    print("Testing walking behavior")
    for ep in range(5):  # Run 5 episodes
        print(f"Episode {ep + 1} of 5")
        obs = env.reset()
        for _ in range(200):  # 200 steps per episode
            frame = env.render(mode='rgb_array', width=400, height=400)
            frames.append(frame[::-1, :, :])  # Flip vertically if needed
            o = env.get_obs()
            a = model.predict(o)[0]
            # Handle 5-tuple return in testing too
            next_o, r, terminated, truncated, info = env.step(a)
            done = terminated or truncated
            if done:
                break
    env.close()

    # Save video
    os.makedirs('videos', exist_ok=True)
    skvideo.io.vwrite('videos/leg_walk.mp4', np.asarray(frames), outputdict={"-pix_fmt": "yuv420p"})
    print("Video saved as 'videos/leg_walk.mp4'")

# Main execution
if __name__ == "__main__":
    # Train the model
    trained_model = train_ppo(env_id="myoLegWalk-v0", total_timesteps=1_000_000)
    
    # Test the trained model
    test_model(trained_model, env_id="myoLegWalk-v0")
# Out:
# Initializing environment...
# Environment initialized.
# Using device: cuda
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# PPO model initialized.
# EvalCallback initialized.
# Starting training...
# Logging to ./ppo_myo_tensorboard/PPO_11
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.2     |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    fps             | 235      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.1        |
# |    ep_rew_mean          | -224        |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.025323499 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -114        |
# |    explained_variance   | -0.00346    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0768     |
# |    std                  | 1           |
# |    value_loss           | 3.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.5        |
# |    ep_rew_mean          | -226        |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 3           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.029211208 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -114        |
# |    explained_variance   | -0.000648   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0929     |
# |    std                  | 1.01        |
# |    value_loss           | 3.32e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 36.1       |
# |    ep_rew_mean          | -225       |
# | time/                   |            |
# |    fps                  | 227        |
# |    iterations           | 4          |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02996844 |
# |    clip_fraction        | 0.367      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -114       |
# |    explained_variance   | -0.000204  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.74e+03   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0993    |
# |    std                  | 1.01       |
# |    value_loss           | 3.18e+03   |
# ----------------------------------------
# C:\Users\rahimig.mohammad\.conda\envs\MyoSuite2\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=141.55 +/- 0.00
# Episode length: 25.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 25         |
# |    mean_reward          | 142        |
# | time/                   |            |
# |    total_timesteps      | 10000      |
# | train/                  |            |
# |    approx_kl            | 0.03444995 |
# |    clip_fraction        | 0.399      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -114       |
# |    explained_variance   | -9.41e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.39e+03   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.102     |
# |    std                  | 1.01       |
# |    value_loss           | 2.94e+03   |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.2     |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    fps             | 226      |
# |    iterations      | 5        |
# |    time_elapsed    | 45       |
# |    total_timesteps | 10240    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.2        |
# |    ep_rew_mean          | -226        |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 6           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.036008634 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -115        |
# |    explained_variance   | -5.3e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.102      |
# |    std                  | 1.02        |
# |    value_loss           | 2.83e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.9        |
# |    ep_rew_mean          | -225        |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 7           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.040390946 |
# |    clip_fraction        | 0.423       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -115        |
# |    explained_variance   | -3.42e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.104      |
# |    std                  | 1.02        |
# |    value_loss           | 2.6e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.1        |
# |    ep_rew_mean          | -227        |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 8           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.043400444 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -115        |
# |    explained_variance   | -2.29e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 913         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.105      |
# |    std                  | 1.02        |
# |    value_loss           | 2.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.6        |
# |    ep_rew_mean          | -224        |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 9           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.048745245 |
# |    clip_fraction        | 0.469       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -115        |
# |    explained_variance   | -1.51e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 881         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.108      |
# |    std                  | 1.03        |
# |    value_loss           | 2.4e+03     |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=127.72 +/- 0.00
# Episode length: 26.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 26          |
# |    mean_reward          | 128         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.052864004 |
# |    clip_fraction        | 0.496       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | -1.08e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.108      |
# |    std                  | 1.03        |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.4     |
# |    ep_rew_mean     | -224     |
# | time/              |          |
# |    fps             | 228      |
# |    iterations      | 10       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 20480    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.8       |
# |    ep_rew_mean          | -227       |
# | time/                   |            |
# |    fps                  | 229        |
# |    iterations           | 11         |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.06056778 |
# |    clip_fraction        | 0.516      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -116       |
# |    explained_variance   | -7.99e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.26e+03   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.109     |
# |    std                  | 1.04       |
# |    value_loss           | 2.24e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36          |
# |    ep_rew_mean          | -227        |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 12          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.061899085 |
# |    clip_fraction        | 0.521       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | -5.36e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.105      |
# |    std                  | 1.04        |
# |    value_loss           | 2.29e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.6       |
# |    ep_rew_mean          | -227       |
# | time/                   |            |
# |    fps                  | 230        |
# |    iterations           | 13         |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.16508953 |
# |    clip_fraction        | 0.576      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -117       |
# |    explained_variance   | -4.41e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 713        |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0975    |
# |    std                  | 1.05       |
# |    value_loss           | 2.22e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.9       |
# |    ep_rew_mean          | -230       |
# | time/                   |            |
# |    fps                  | 230        |
# |    iterations           | 14         |
# |    time_elapsed         | 124        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.09071171 |
# |    clip_fraction        | 0.575      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -118       |
# |    explained_variance   | -3.22e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.09e+03   |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.102     |
# |    std                  | 1.05       |
# |    value_loss           | 2.28e+03   |
# ----------------------------------------
# Eval num_timesteps=30000, episode_reward=186.59 +/- 0.00
# Episode length: 32.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 32         |
# |    mean_reward          | 187        |
# | time/                   |            |
# |    total_timesteps      | 30000      |
# | train/                  |            |
# |    approx_kl            | 0.20486677 |
# |    clip_fraction        | 0.682      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -118       |
# |    explained_variance   | -2.15e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.19e+03   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0465    |
# |    std                  | 1.06       |
# |    value_loss           | 2.33e+03   |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.4     |
# |    ep_rew_mean     | -227     |
# | time/              |          |
# |    fps             | 229      |
# |    iterations      | 15       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 30720    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35         |
# |    ep_rew_mean          | -226       |
# | time/                   |            |
# |    fps                  | 230        |
# |    iterations           | 16         |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.17886375 |
# |    clip_fraction        | 0.735      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -118       |
# |    explained_variance   | -1.67e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.24e+03   |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00962   |
# |    std                  | 1.07       |
# |    value_loss           | 2.35e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 36.3      |
# |    ep_rew_mean          | -234      |
# | time/                   |           |
# |    fps                  | 230       |
# |    iterations           | 17        |
# |    time_elapsed         | 151       |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.21844   |
# |    clip_fraction        | 0.723     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -119      |
# |    explained_variance   | -1.19e-06 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.05e+03  |
# |    n_updates            | 160       |
# |    policy_gradient_loss | 0.00798   |
# |    std                  | 1.07      |
# |    value_loss           | 2.43e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 36         |
# |    ep_rew_mean          | -232       |
# | time/                   |            |
# |    fps                  | 230        |
# |    iterations           | 18         |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.19966558 |
# |    clip_fraction        | 0.605      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -119       |
# |    explained_variance   | -7.15e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.22e+03   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.035     |
# |    std                  | 1.08       |
# |    value_loss           | 2.59e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.4       |
# |    ep_rew_mean          | -230       |
# | time/                   |            |
# |    fps                  | 229        |
# |    iterations           | 19         |
# |    time_elapsed         | 169        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.14635977 |
# |    clip_fraction        | 0.627      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -120       |
# |    explained_variance   | -5.96e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.69e+03   |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0349    |
# |    std                  | 1.08       |
# |    value_loss           | 2.6e+03    |
# ----------------------------------------
# Eval num_timesteps=40000, episode_reward=99.97 +/- 0.00
# Episode length: 28.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 28         |
# |    mean_reward          | 100        |
# | time/                   |            |
# |    total_timesteps      | 40000      |
# | train/                  |            |
# |    approx_kl            | 0.09948661 |
# |    clip_fraction        | 0.577      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -120       |
# |    explained_variance   | -2.38e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.18e+03   |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0534    |
# |    std                  | 1.09       |
# |    value_loss           | 2.69e+03   |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.3     |
# |    ep_rew_mean     | -231     |
# | time/              |          |
# |    fps             | 227      |
# |    iterations      | 20       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 40960    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.8        |
# |    ep_rew_mean          | -228        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 21          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.056503743 |
# |    clip_fraction        | 0.555       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -120        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 852         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0521     |
# |    std                  | 1.09        |
# |    value_loss           | 2.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.8        |
# |    ep_rew_mean          | -229        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 22          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008658245 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 449         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 1.09        |
# |    value_loss           | 1.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.7        |
# |    ep_rew_mean          | -233        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 23          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009607145 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 383         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0352     |
# |    std                  | 1.09        |
# |    value_loss           | 833         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.1        |
# |    ep_rew_mean          | -230        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 24          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009082252 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 291         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0364     |
# |    std                  | 1.09        |
# |    value_loss           | 647         |
# -----------------------------------------
# Eval num_timesteps=50000, episode_reward=115.75 +/- 0.00
# Episode length: 29.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 29          |
# |    mean_reward          | 116         |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.012148608 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 166         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0462     |
# |    std                  | 1.09        |
# |    value_loss           | 543         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35       |
# |    ep_rew_mean     | -230     |
# | time/              |          |
# |    fps             | 225      |
# |    iterations      | 25       |
# |    time_elapsed    | 227      |
# |    total_timesteps | 51200    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.3        |
# |    ep_rew_mean          | -231        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 26          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012854925 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 329         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0498     |
# |    std                  | 1.1         |
# |    value_loss           | 466         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35          |
# |    ep_rew_mean          | -228        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 27          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.014862841 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 164         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0511     |
# |    std                  | 1.1         |
# |    value_loss           | 378         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.7        |
# |    ep_rew_mean          | -233        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 28          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016249105 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 163         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0538     |
# |    std                  | 1.1         |
# |    value_loss           | 385         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.8        |
# |    ep_rew_mean          | -234        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 29          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.016154604 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 168         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0577     |
# |    std                  | 1.1         |
# |    value_loss           | 379         |
# -----------------------------------------
# Eval num_timesteps=60000, episode_reward=136.03 +/- 0.00
# Episode length: 29.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 29          |
# |    mean_reward          | 136         |
# | time/                   |             |
# |    total_timesteps      | 60000       |
# | train/                  |             |
# |    approx_kl            | 0.015579468 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0577     |
# |    std                  | 1.1         |
# |    value_loss           | 317         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35       |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    fps             | 225      |
# |    iterations      | 30       |
# |    time_elapsed    | 272      |
# |    total_timesteps | 61440    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.1        |
# |    ep_rew_mean          | -231        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 31          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.018484857 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 148         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0599     |
# |    std                  | 1.1         |
# |    value_loss           | 303         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.2        |
# |    ep_rew_mean          | -231        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 32          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.020201664 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.6        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0624     |
# |    std                  | 1.1         |
# |    value_loss           | 292         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.6        |
# |    ep_rew_mean          | -229        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 33          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.020564515 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.4        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0648     |
# |    std                  | 1.1         |
# |    value_loss           | 235         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.9        |
# |    ep_rew_mean          | -231        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 34          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.022054762 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.5        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0681     |
# |    std                  | 1.1         |
# |    value_loss           | 198         |
# -----------------------------------------
# Eval num_timesteps=70000, episode_reward=104.42 +/- 0.00
# Episode length: 31.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 31          |
# |    mean_reward          | 104         |
# | time/                   |             |
# |    total_timesteps      | 70000       |
# | train/                  |             |
# |    approx_kl            | 0.026331494 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -121        |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 100         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.065      |
# |    std                  | 1.11        |
# |    value_loss           | 192         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.5     |
# |    ep_rew_mean     | -234     |
# | time/              |          |
# |    fps             | 225      |
# |    iterations      | 35       |
# |    time_elapsed    | 318      |
# |    total_timesteps | 71680    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.5        |
# |    ep_rew_mean          | -228        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 36          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.028057817 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -122        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.9        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0642     |
# |    std                  | 1.11        |
# |    value_loss           | 182         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.8        |
# |    ep_rew_mean          | -229        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 37          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.028735816 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -122        |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0663     |
# |    std                  | 1.11        |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.7        |
# |    ep_rew_mean          | -229        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 38          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.027936563 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -122        |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0647     |
# |    std                  | 1.11        |
# |    value_loss           | 146         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.2       |
# |    ep_rew_mean          | -233       |
# | time/                   |            |
# |    fps                  | 225        |
# |    iterations           | 39         |
# |    time_elapsed         | 354        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03228379 |
# |    clip_fraction        | 0.385      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -122       |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 48.1       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0704    |
# |    std                  | 1.11       |
# |    value_loss           | 110        |
# ----------------------------------------
# Eval num_timesteps=80000, episode_reward=122.88 +/- 0.00
# Episode length: 31.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 31          |
# |    mean_reward          | 123         |
# | time/                   |             |
# |    total_timesteps      | 80000       |
# | train/                  |             |
# |    approx_kl            | 0.035862118 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -122        |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0653     |
# |    std                  | 1.12        |
# |    value_loss           | 123         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | -231     |
# | time/              |          |
# |    fps             | 225      |
# |    iterations      | 40       |
# |    time_elapsed    | 363      |
# |    total_timesteps | 81920    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.8       |
# |    ep_rew_mean          | -226       |
# | time/                   |            |
# |    fps                  | 224        |
# |    iterations           | 41         |
# |    time_elapsed         | 374        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.03357185 |
# |    clip_fraction        | 0.376      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -122       |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 56.3       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0637    |
# |    std                  | 1.12       |
# |    value_loss           | 102        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.3        |
# |    ep_rew_mean          | -228        |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 42          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.041152995 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -123        |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0645     |
# |    std                  | 1.12        |
# |    value_loss           | 77.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.3        |
# |    ep_rew_mean          | -234        |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 43          |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.038246248 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -123        |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.5        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.067      |
# |    std                  | 1.13        |
# |    value_loss           | 79.8        |
# -----------------------------------------
# Eval num_timesteps=90000, episode_reward=91.40 +/- 0.00
# Episode length: 31.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 31         |
# |    mean_reward          | 91.4       |
# | time/                   |            |
# |    total_timesteps      | 90000      |
# | train/                  |            |
# |    approx_kl            | 0.03727994 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -123       |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.8       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0732    |
# |    std                  | 1.13       |
# |    value_loss           | 88.1       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.3     |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    fps             | 223      |
# |    iterations      | 44       |
# |    time_elapsed    | 402      |
# |    total_timesteps | 90112    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34         |
# |    ep_rew_mean          | -228       |
# | time/                   |            |
# |    fps                  | 223        |
# |    iterations           | 45         |
# |    time_elapsed         | 411        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.04251045 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -123       |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.8       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0692    |
# |    std                  | 1.13       |
# |    value_loss           | 74.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34.1       |
# |    ep_rew_mean          | -227       |
# | time/                   |            |
# |    fps                  | 223        |
# |    iterations           | 46         |
# |    time_elapsed         | 421        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.03916159 |
# |    clip_fraction        | 0.427      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -123       |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 55.3       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.07      |
# |    std                  | 1.13       |
# |    value_loss           | 80.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.4        |
# |    ep_rew_mean          | -230        |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 47          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.042957176 |
# |    clip_fraction        | 0.425       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -124        |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.1        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.072      |
# |    std                  | 1.14        |
# |    value_loss           | 76.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.8        |
# |    ep_rew_mean          | -228        |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 48          |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.049127735 |
# |    clip_fraction        | 0.469       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -124        |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0716     |
# |    std                  | 1.14        |
# |    value_loss           | 69.4        |
# -----------------------------------------
# Eval num_timesteps=100000, episode_reward=70.02 +/- 0.00
# Episode length: 29.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 29         |
# |    mean_reward          | 70         |
# | time/                   |            |
# |    total_timesteps      | 100000     |
# | train/                  |            |
# |    approx_kl            | 0.04879784 |
# |    clip_fraction        | 0.439      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -124       |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.6       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0728    |
# |    std                  | 1.14       |
# |    value_loss           | 62.5       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34       |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    fps             | 221      |
# |    iterations      | 49       |
# |    time_elapsed    | 452      |
# |    total_timesteps | 100352   |
# ...
# |    loss                 | 2.41       |
# |    n_updates            | 4730       |
# |    policy_gradient_loss | -0.0636    |
# |    std                  | 3.79       |
# |    value_loss           | 7.06       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.2     |
# |    ep_rew_mean     | -179     |
# | time/              |          |
# |    fps             | 222      |
# |    iterations      | 474      |
# |    time_elapsed    | 4368     |
# |    total_timesteps | 970752   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18.1       |
# |    ep_rew_mean          | -178       |
# | time/                   |            |
# |    fps                  | 222        |
# |    iterations           | 475        |
# |    time_elapsed         | 4378       |
# |    total_timesteps      | 972800     |
# | train/                  |            |
# |    approx_kl            | 0.06850092 |
# |    clip_fraction        | 0.466      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -217       |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.123     |
# |    n_updates            | 4740       |
# |    policy_gradient_loss | -0.0652    |
# |    std                  | 3.8        |
# |    value_loss           | 4.82       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18.2       |
# |    ep_rew_mean          | -179       |
# | time/                   |            |
# |    fps                  | 222        |
# |    iterations           | 476        |
# |    time_elapsed         | 4387       |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.04028075 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -217       |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.423     |
# |    n_updates            | 4750       |
# |    policy_gradient_loss | -0.0641    |
# |    std                  | 3.81       |
# |    value_loss           | 5.73       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18.1       |
# |    ep_rew_mean          | -179       |
# | time/                   |            |
# |    fps                  | 222        |
# |    iterations           | 477        |
# |    time_elapsed         | 4396       |
# |    total_timesteps      | 976896     |
# | train/                  |            |
# |    approx_kl            | 0.05318211 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -218       |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.827     |
# |    n_updates            | 4760       |
# |    policy_gradient_loss | -0.0644    |
# |    std                  | 3.82       |
# |    value_loss           | 4.74       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.3        |
# |    ep_rew_mean          | -179        |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 478         |
# |    time_elapsed         | 4404        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.049596798 |
# |    clip_fraction        | 0.452       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -218        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.781      |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.0624     |
# |    std                  | 3.84        |
# |    value_loss           | 5.37        |
# -----------------------------------------
# Eval num_timesteps=980000, episode_reward=-116.27 +/- 0.00
# Episode length: 15.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 15          |
# |    mean_reward          | -116        |
# | time/                   |             |
# |    total_timesteps      | 980000      |
# | train/                  |             |
# |    approx_kl            | 0.058445223 |
# |    clip_fraction        | 0.493       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -218        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.01       |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.0663     |
# |    std                  | 3.85        |
# |    value_loss           | 4.11        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.1     |
# |    ep_rew_mean     | -178     |
# | time/              |          |
# |    fps             | 222      |
# |    iterations      | 479      |
# |    time_elapsed    | 4414     |
# |    total_timesteps | 980992   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.2        |
# |    ep_rew_mean          | -179        |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 480         |
# |    time_elapsed         | 4423        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.050106473 |
# |    clip_fraction        | 0.48        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -218        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.94       |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.0685     |
# |    std                  | 3.86        |
# |    value_loss           | 4.25        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 18.1      |
# |    ep_rew_mean          | -178      |
# | time/                   |           |
# |    fps                  | 222       |
# |    iterations           | 481       |
# |    time_elapsed         | 4432      |
# |    total_timesteps      | 985088    |
# | train/                  |           |
# |    approx_kl            | 0.0483628 |
# |    clip_fraction        | 0.46      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -219      |
# |    explained_variance   | 0.997     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.942    |
# |    n_updates            | 4800      |
# |    policy_gradient_loss | -0.0644   |
# |    std                  | 3.87      |
# |    value_loss           | 4.4       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18         |
# |    ep_rew_mean          | -177       |
# | time/                   |            |
# |    fps                  | 222        |
# |    iterations           | 482        |
# |    time_elapsed         | 4441       |
# |    total_timesteps      | 987136     |
# | train/                  |            |
# |    approx_kl            | 0.05227366 |
# |    clip_fraction        | 0.438      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -219       |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.55       |
# |    n_updates            | 4810       |
# |    policy_gradient_loss | -0.06      |
# |    std                  | 3.87       |
# |    value_loss           | 4.19       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.9        |
# |    ep_rew_mean          | -176        |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 483         |
# |    time_elapsed         | 4450        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.045566566 |
# |    clip_fraction        | 0.431       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -219        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.406      |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.0623     |
# |    std                  | 3.88        |
# |    value_loss           | 4.88        |
# -----------------------------------------
# Eval num_timesteps=990000, episode_reward=-116.50 +/- 0.00
# Episode length: 15.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 15          |
# |    mean_reward          | -117        |
# | time/                   |             |
# |    total_timesteps      | 990000      |
# | train/                  |             |
# |    approx_kl            | 0.047315806 |
# |    clip_fraction        | 0.47        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -219        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.852      |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.0695     |
# |    std                  | 3.89        |
# |    value_loss           | 4.3         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.1     |
# |    ep_rew_mean     | -179     |
# | time/              |          |
# |    fps             | 222      |
# |    iterations      | 484      |
# |    time_elapsed    | 4459     |
# |    total_timesteps | 991232   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.3        |
# |    ep_rew_mean          | -179        |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 485         |
# |    time_elapsed         | 4468        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.036086373 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -219        |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.955      |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.0456     |
# |    std                  | 3.9         |
# |    value_loss           | 6.65        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18.1       |
# |    ep_rew_mean          | -178       |
# | time/                   |            |
# |    fps                  | 222        |
# |    iterations           | 486        |
# |    time_elapsed         | 4477       |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.04331632 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -219       |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.138      |
# |    n_updates            | 4850       |
# |    policy_gradient_loss | -0.0616    |
# |    std                  | 3.91       |
# |    value_loss           | 4.4        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18.1       |
# |    ep_rew_mean          | -178       |
# | time/                   |            |
# |    fps                  | 222        |
# |    iterations           | 487        |
# |    time_elapsed         | 4486       |
# |    total_timesteps      | 997376     |
# | train/                  |            |
# |    approx_kl            | 0.04981281 |
# |    clip_fraction        | 0.397      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -220       |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -1.04      |
# |    n_updates            | 4860       |
# |    policy_gradient_loss | -0.0647    |
# |    std                  | 3.91       |
# |    value_loss           | 4.69       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.2        |
# |    ep_rew_mean          | -179        |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 488         |
# |    time_elapsed         | 4494        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.050378796 |
# |    clip_fraction        | 0.427       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -220        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03        |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.0627     |
# |    std                  | 3.93        |
# |    value_loss           | 4.1         |
# -----------------------------------------
# Eval num_timesteps=1000000, episode_reward=-114.91 +/- 0.00
# Episode length: 15.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 15         |
# |    mean_reward          | -115       |
# | time/                   |            |
# |    total_timesteps      | 1000000    |
# | train/                  |            |
# |    approx_kl            | 0.04462298 |
# |    clip_fraction        | 0.419      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -220       |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.242      |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.0637    |
# |    std                  | 3.94       |
# |    value_loss           | 6.08       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.3     |
# |    ep_rew_mean     | -179     |
# | time/              |          |
# |    fps             | 222      |
# |    iterations      | 489      |
# |    time_elapsed    | 4504     |
# |    total_timesteps | 1001472  |
# ---------------------------------
# Training completed.
# Model saved.
# Initializing test environment...
# Testing walking behavior
# Episode 1 of 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 135
#     132 trained_model = train_ppo(env_id="myoLegWalk-v0", total_timesteps=1_000_000)
#     134 # Test the trained model
# --> 135 test_model(trained_model, env_id="myoLegWalk-v0")
#
# Cell In[16], line 113, in test_model(model, env_id)
#     111 obs = env.reset()
#     112 for _ in range(200):  # 200 steps per episode
# --> 113     frame = env.render(mode='rgb_array', width=400, height=400)
#     114     frames.append(frame[::-1, :, :])  # Flip vertically if needed
#     115     o = env.get_obs()
#
# TypeError: render() got an unexpected keyword argument 'mode'
